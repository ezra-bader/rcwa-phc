# %% [markdown]
# # **ReS<sub>2</sub> Example**
# ### Calculating reflection and transmission of a patterned ReS<sub>2</sub> flake. Powered by [$S^4$](https://web.stanford.edu/group/fan/S4/). Credit due to Victor Liu (Fan Group, Stanford Electrical Engineering Department, 2012).
#
# #### This notebook version written by Ezra Bader (Menon Group / LaNMP, CCNY, May 2026) with help from Dr. Claude (Anthropic).
#
# <div style="display: flex; justify-content: left; align-items: center; gap: 20px;">
#
# <!-- <img src="https://web.stanford.edu/group/fan/S4/_images/schem_640.png" alt="schematic" width="400" style="border: 5px solid maroon;"> -->
#
# <img src="res2CuboidsImage.png" alt="crsbr" width="700" style="border: 5px solid maroon;">
#
# </div>
#
# <span style="font-size:30px;">**Workflow:**</span>
#
# <span style="font-size:20px;">**1.** Imports</span>
#
# <span style="font-size:20px;">**2.** Lattice & layers</span>
#
# <span style="font-size:20px;">**3.** Configure parameters</span>
#
# <span style="font-size:20px;">**4.** Verify/plot unit cell, refractive index</span>
#
# <span style="font-size:20px;">**5.** Convergence and spot tests</span>
#
# <span style="font-size:20px;">**6.** Run studies or load data</span>
#
# <span style="font-size:17px;"> &emsp; 6.0.1 — Quick checks, run study 0 (reflection)</span>
#
# <span style="font-size:17px;"> &emsp; 6.1.1 — Run study 1 (E vs. k)</span>
#
# <span style="font-size:17px;"> &emsp; 6.2.1 — Run study 2 (kx, ky)</span>
#
# <span style="font-size:17px;"> &emsp; 6.3.1 — Run study 3 (mode calculation)</span>
#
# <span style="font-size:20px;">**7.** Plotting</span>
#
# <span style="font-size:20px;">**8.** Examples</span>
#
# ### Under construction --
#
# <span style="font-size:20px;">**??.** GUI
#
# <span style="font-size:20px;">**??.** Polarization vortex analysis

# %% [markdown]
# -------------------
# # **Requirements**
# ### All standard python libraries will import automatically. If a library is not found, you probably haven't installed it in your environment. If you are using a conda environment, for example, and \<library-name\> is not found, you'll run the following in your command line:
#
# ```bash
# conda activate <your-env-name>
# conda install <library-name>
# ```
#
# ### Slightly more complicated is S4, which should be built from the source code. Unix-like environment and C++ compiler required—on Windows, you'll have to use something like WSL (Windows Subsystem for Linux). Then in the terminal:
#
# ```bash
# cd ~/your-project-folder
# git clone https://github.com/victorliu/S4.git
# ```
#
# ### Nothing else is technically required, but [the authors recommend](https://web.stanford.edu/group/fan/S4/install.html) certain additional packages. Once you've flagged these in your Makefile:
#
# ```bash
# make lib
# make S4_pyext
# ```

# %% [markdown]
# # **1. Imports**

# %%
import rcwa_utils as ru     # NOTE: Imports all the necessary helper functions to run this notebook.
from rcwa_utils import *    
import S4                   # NOTE: Your python environment must have a valid S4 installation
import numpy as np
import pandas as pd
from abc import ABC, abstractmethod
import threading
import time, warnings, itertools
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import matplotlib.animation as animation
from matplotlib.animation import FFMpegWriter
from scipy.interpolate import interp1d, griddata
from pathlib import Path
from joblib import Parallel, delayed
import re as _re
from datetime import datetime as _dt
import matplotlib.animation as animation
from matplotlib.animation import FFMpegWriter
from scipy.interpolate import griddata
import tkinter as tk
from tkinter import filedialog
import tempfile
import os
import shutil
import importlib
from dataclasses import dataclass, field
importlib.reload(ru)

MATERIALS = load_material_library()
# Out:
# Material library loaded. Currently supported materials:
# Air, Si, SiO2, TiO2, SiN, CrSBr, MoOCl2, ReS2, LC, SMILES

# %% [markdown]
# # **2. Layers**

# %% [markdown]
# For each layer specify a <span style="color:#9CDCFE">**MATERIAL**</span> and <span style="color:#9CDCFE">**THICKNESS**</span> (nm). Lattice constant will be set in the next cell.
#
# Optional arguments:
#
# <span style="color:#9CDCFE">**PATTERN**</span>  — Currently supported: 'hole', 'pillar', 'cuboids'.
#
# <span style="color:#9CDCFE">**ROT (°)**</span>      — Rotates permittivity tensor $\bm{\epsilon_{ij}}$ about $\bm{\hat{z}}$.
#
# ```python
# # EXAMPLE CALLS:
#
# MY_LAYERS1 = [
#     ru.Layer('Air',    500,    pattern=None),
#     ru.Layer('SiO2',   50,     pattern='hole', ff=0.5),
#     ru.Layer('CrSBr',  70,     pattern='hole', ff=0.5, layer_rot=45),
#     ru.Layer('Air',    500,    pattern=None)
# ]
#
# MY_LAYERS2 = [
#     ru.Layer('Air',    500,    pattern=None),
#     ru.Layer('ReS2',   90,     pattern='cuboids', w0=250, alpha=0.6),
#     ru.Layer('Air',    500,    pattern=None)
# ]
# ```

# %%
# ╔══════════════════════════════════════════════════════════════════════════╗
# ║       LAYERS  (top to bottom; pick material, thickness in nm)            ║
# ╚══════════════════════════════════════════════════════════════════════════╝

# NOTE: Stack is built top down, where the first layer starts at z=0 and ends at z=|layer_thickness|.
#       The "transmission" side will be the LAST layer in the following list.
#       Since RCWA is all plane waves, the actual orientation of your stack
#       shouldn't matter UNLESS your materials break reciprocity! Then you can no longer safely
#       exchange source & detector.

MY_LAYERS = [
    Layer('Air',    500,     pattern=None),
    Layer('ReS2',  70,     pattern='cuboids', w0=250, alpha=0.6),
    # Layer('SiO2',    90),
    # Layer('Si', 100),
    Layer('Air',    500,     pattern=None)
]

# check_layers(layers=MY_LAYERS)

# %% [markdown]
# # **3. Configure Parameters**

# %%
# ╔══════════════════════════════════════════════════════════════════════════╗
# ║                          SWEEP CONFIG.                                   ║
# ╚══════════════════════════════════════════════════════════════════════════╝

conf = RCWAConfig(
    layers = MY_LAYERS,
    lattice_const = 535.0,          # Lattice constant (a, 0), (0, a); planning to add support for arbitrary lattice vectors
    lam_start = 810,                # Start wavelength in calculation
    lam_stop = 860,                # End wavelength in calculation
    lam_step = 0.75,                   # Wavelength step
    n_basis = 25,                   # Number of fourier basis functions
    n_grid = 10,                    # Number of lateral grid points to sample (don't really need to change ever)
    n_jobs = 8,                     # Number of parallel jobs (must be ≤ number of CPU cores)
    global_rot = 0,                 # Global index tensor rotation around ẑ
    # save_to='default',            # Save directory, 'default' will make a new folder called rcwa_output in the same directory as the notebook
    save_to = '/Users/ezra/Desktop/LaNMP/python_scripts/RCWA/globalVersion/rcwa_output/ReS2Example',

    # Defining study 1, E vs. k
    study1 = Study1Config(
        elev_max = 30.0,            # Maximum angle for dispersion study (°)
        elev_n = 90,                # Number of angle samples (from -elev_max --> +elev_max)
        azim_vals = [0.0, 90.0]     # Which axes to measure along, measured in azimuthal angle (°)
    ),

    # Defining study 2, kx vs. ky
    study2 = Study2Config(
        elev_max = 30.0,
        elev_n = 65,
        azim_n_max = 180,
        azim_n_min = 100
    )
)

conf.verify_config()
# Out:
# layer   material    thickness (nm)        pattern                 rot (°)
# --------------------------------------------------------------------------
# 0       Air         500                   None                    0
# 1       ReS2        70                    cuboids, w0=250, a=0.6  0
# 2       Air         500                   None                    0
#
# Wavelengths: 810–860 nm (68 pts)
# Study 1: 90 elev × 2 azim = 180 pairs
# Study 2: 7700 (azim, elev) pairs
# Workers: 8  |  N_BASIS: 25
#
# Output directory: /Users/ezra/Desktop/LaNMP/python_scripts/RCWA/globalVersion/rcwa_output/ReS2Example

# %% [markdown]
# # **4. Unit Cell and Refractive Index Plots**

# %%
importlib.reload(ru)
# Out:
# <module 'rcwa_utils' from '/Users/ezra/gitprojects/rcwa-phc/rcwa_utils.py'>

# %%
# indexplot = ru.plot_refractive_index(conf,layers=None,materials=None,lam_min=None,lam_max=None,n_pts=600)
# indexplot = ru.plot_refractive_index(conf, lam_min = 500, lam_max= 600)
unitcellplot = ru.plot_unit_cell(conf, save_fig = False)

# %% [markdown]
# # **5. Convergence tests**

# %%
convergence_test(conf, basis_vals=(1, 4, 25, 49))
convergence_test_phase(conf, basis_vals=(1, 4, 25, 49))
scan_wavelengths(conf)
verify_energy_conservation(conf)
# Out:
# %--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--
# Convergence test: λ=950 nm  elev=5.0°  azim=0°  rot=0°
# Stack: Layer(Air, 500.00nm) | Layer(SiO2, 50.00nm, hole, ff=0.5) | Layer(CrSBr, 100.00nm, hole, ff=0.5) | Layer(SiO2, 90.00nm) | Layer(Si, 100.00nm) | Layer(Air, 500.00nm)
# |   NumBasis        T_ss        T_pp     |dT_ss|    time(ms)
# |          1     0.16434     0.22222         nan        30.2
# |          4     0.16434     0.22222     0.00000         0.4
# |         25     0.11481     0.27154     0.04953        56.0
# |         49     0.11475     0.28326     0.00006       282.9
# %--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--
# Phase convergence: λ=950 nm  elev=5.0°  azim=0°    rot=0°
# |   NumBasis      |t_ss|    phase_ss (deg)          CD    time(ms)
# |          1     0.33884           -49.676     0.00000        54.1
# |          4     0.33884           -49.676     0.00000        50.8
# |         25     0.33884           -49.676     0.00000        46.0
# |         49     0.33884           -49.676     0.00000        49.8
# %--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--
# Wavelength scan: elev=0.0°  azim=0°  rot=0°      N_BASIS=25
#   lam (nm)   energy (eV)        T_ss        T_pp     T_ss+T_pp
#      850.0        1.4586     0.07342     0.25044       0.32386
#      854.0        1.4518     0.09046     0.20184       0.29229
#      858.0        1.4450     0.10388     0.14800       0.25189
#      862.0        1.4383     0.11498     0.10586       0.22084
#      866.0        1.4316     0.12541     0.07969       0.20510
#      870.0        1.4251     0.13734     0.06278       0.20012
#      874.0        1.4185     0.15410     0.04533       0.19943
#      878.0        1.4121     0.18402     0.02678       0.21079
#      882.0        1.4057     0.21109     0.01422       0.22531
#      886.0        1.3993     0.04383     0.01002       0.05385
#      890.0        1.3930     0.06195     0.00873       0.07067
#      894.0        1.3868     0.08565     0.00288       0.08853
#      898.0        1.3806     0.07929     0.00213       0.08142
#      902.0        1.3745     0.08949     0.00359       0.09307
#      906.0        1.3684     0.10246     0.00649       0.10895
#      910.0        1.3624     0.10510     0.00157       0.10666
#      914.0        1.3565     0.09318     0.01438       0.10756
#      918.0        1.3505     0.10705     0.01115       0.11820
#      922.0        1.3447     0.11484     0.04061       0.15544
#      926.0        1.3389     0.11715     0.12899       0.24615
#      930.0        1.3331     0.11898     0.17083       0.28981
#      934.0        1.3274     0.12063     0.30631       0.42694
#      938.0        1.3217     0.12230     0.16891       0.29122
#      942.0        1.3161     0.12425     0.42530       0.54956
#      946.0        1.3106     0.12700     0.37058       0.49758
#      950.0        1.3051     0.13230     0.29842       0.43072
#      954.0        1.2996     0.14666     0.25106       0.39773
#      958.0        1.2942     0.09618     0.22151       0.31769
#      962.0        1.2888     0.11184     0.20290       0.31474
#      966.0        1.2834     0.11643     0.19128       0.30772
#      970.0        1.2781     0.11882     0.18448       0.30331
#      974.0        1.2729     0.12043     0.18133       0.30177
#      978.0        1.2677     0.12169     0.18128       0.30297
#      982.0        1.2625     0.12275     0.18424       0.30699
#      986.0        1.2574     0.12372     0.19054       0.31426
#      990.0        1.2523     0.12462     0.20106       0.32568
#      994.0        1.2473     0.12550     0.21756       0.34306
#      998.0        1.2423     0.12636     0.24334       0.36970
#     1002.0        1.2373     0.12723     0.28404       0.41127
#     1006.0        1.2324     0.12811     0.34346       0.47157
#     1010.0        1.2275     0.12900     0.36597       0.49497
#     1014.0        1.2227     0.12991     0.17288       0.30279
#     1018.0        1.2179     0.13085     0.02286       0.15371
#     1022.0        1.2131     0.13182     0.00189       0.13371
#     1026.0        1.2084     0.13282     0.01080       0.14362
#     1030.0        1.2037     0.13386     0.02283       0.15669
#     1034.0        1.1990     0.13493     0.03344       0.16837
#     1038.0        1.1944     0.13605     0.04222       0.17826
#     1042.0        1.1898     0.13720     0.04948       0.18668
#     1046.0        1.1853     0.13840     0.05558       0.19398
#     1050.0        1.1808     0.13965     0.06080       0.20045
# %--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--
# Energy conservation check:
# |  λ=950 nm  elev=10.0°  azim=0°  rot=0°
# |  Stack: Layer(Air, 500.00nm) | Layer(SiO2, 50.00nm, hole, ff=0.5) | Layer(CrSBr, 100.00nm, hole, ff=0.5) | Layer(SiO2, 90.00nm) | Layer(Si, 100.00nm) | Layer(Air, 500.00nm)
# |  Incident medium: Air  |  Substrate: Air
# Jones T matrix:
# |           s-in           p-in
# |  s-out  +0.1981-0.2386j   -0.0000-0.0000j
# |  p-out  -0.0000+0.0000j   -0.4149+0.1149j
# V
#  input     T_jones        T_pf        R_pf           A       T+R+A
# --------------------------------------------------------------------
#   s-in     0.09618     0.09767     0.88277     0.01956    1.000000
#   p-in     0.18534     0.18253     0.66689     0.15058    1.000000

# %% [markdown]
# # **6. Run Studies**

# %% [markdown]
# ### **6.0.1 Quick Tests & Study 0 (reflection)**

# %%
qs1 = ru.quick_test_study1(conf)
# Out:
# Study 1: 8 pairs  |  8 workers
#   P=500 nm  |  Air 500nm  |  SiO2 50nm (hole ff=0.5)  |  CrSBr 100nm (hole ff=0.5)  |  SiO2 90nm  |  Si 100nm  |  Air 500nm
#   Study 1 [1/8  12%]  0.1 min elapsed,  ETC: 0.7 min  (5.6 s/task)
#   Study 1 [2/8  25%]  0.1 min elapsed,  ETC: 0.3 min  (2.8 s/task)
#   Study 1 [3/8  38%]  0.1 min elapsed,  ETC: 0.2 min  (1.9 s/task)
#   Study 1 [4/8  50%]  0.1 min elapsed,  ETC: 0.1 min  (1.4 s/task)
#   Study 1 [5/8  62%]  0.1 min elapsed,  ETC: 0.1 min  (1.1 s/task)
#   Study 1 [6/8  75%]  0.1 min elapsed,  ETC: 0.0 min  (0.9 s/task)
#   Study 1 [7/8  88%]  0.1 min elapsed,  ETC: 0.0 min  (0.8 s/task)
#   Study 1 [8/8  100%]  0.1 min elapsed,  ETC: 0.0 min  (0.7 s/task)
# Study 1 done in 0.1 min
# %--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--
# /Users/ezra/Desktop/LaNMP/python_scripts/RCWA/globalVersion/rcwa_output/CrSBrexample
# |
# |
# V
# Config saved as study1_A500nm_SiO2-50nm-hole-ff0.5nm_CrSBr-100nm-hole-ff0.5nm_SiO2-90nm_Si-100nm_rot00_nb25.json
# Data saved as study1_A500nm_SiO2-50nm-hole-ff0.5nm_CrSBr-100nm-hole-ff0.5nm_SiO2-90nm_Si-100nm_rot00_nb25.csv (168 rows)

# %% [markdown]
# ### **6.1.1 Study 1 (E vs. k)**

# %%
# df_s1 = run_study1(conf, print_every=32)
df_s1_hd = run_study1(conf, print_every=32)
# Out:
# Study 1: 180 pairs  |  8 workers
#   P=535 nm  |  Air 500nm  |  ReS2 70nm (cuboids w0=250 a=0.6)  |  Air 500nm
#   Study 1 [32/180  18%]  0.3 min elapsed,  ETC: 1.2 min  (0.5 s/task)
#   Study 1 [64/180  36%]  0.5 min elapsed,  ETC: 0.9 min  (0.5 s/task)
#   Study 1 [96/180  53%]  0.7 min elapsed,  ETC: 0.6 min  (0.5 s/task)
#   Study 1 [128/180  71%]  1.0 min elapsed,  ETC: 0.4 min  (0.5 s/task)
#   Study 1 [160/180  89%]  1.2 min elapsed,  ETC: 0.1 min  (0.4 s/task)
#   Study 1 [180/180  100%]  1.3 min elapsed,  ETC: 0.0 min  (0.4 s/task)
# Study 1 done in 1.3 min
# %--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--
# /Users/ezra/Desktop/LaNMP/python_scripts/RCWA/globalVersion/rcwa_output/ReS2Example
# |
# |
# V
# Config saved as study1_A535nm_ReS2-70nm-cub-w0250nm-a0.6_rot00_nb25.json
# Data saved as study1_A535nm_ReS2-70nm-cub-w0250nm-a0.6_rot00_nb25.csv (12240 rows)

# %%
importlib.reload(ru)
# Out:
# <module 'rcwa_utils' from '/Users/ezra/gitprojects/rcwa-phc/rcwa_utils.py'>

# %%
plot1 = ru.plot_study1(df_s1_hd,conf,preset='res2', save_fig=False)

# %%
# Sweep:
a_vals = [500.0]
ff_vals = [0.3, 0.5, 0.7]
rot_vals = [0.0, 45.0]
t_vals = [30.0, 50.0, 80.0]

def make_layers(ff, crsbr_t):
    return [
        ru.Layer('Air', 500),
        ru.Layer('SiO2',  50,      pattern='hole', ff=ff),
        ru.Layer('CrSBr', crsbr_t, pattern='hole', ff=ff),
        ru.Layer('SiO2',  90),
        ru.Layer('Si',    100),
        ru.Layer('Air', 500)
    ]

for a, ff, rot, crsbr_t in itertools.product(
    a_vals,
    ff_vals,
    rot_vals,
    t_vals
    ):

    if not (ff == 0.3 and rot == 0.0): #had to restart sweep because of busted settings, but some runs were still good
        sweepconf = dataclasses.replace(conf,
            lattice_const = float(a),
            layers = make_layers(ff, crsbr_t),
            global_rot = rot
        )

        df = ru.run_study1(sweepconf, print_every=64)

        fig   = ru.plot_study1(df, sweepconf, rot_deg = rot, preset='totalstokes', save_fig=True)
        plt.close(fig)   # free memory between plots
# Out:
# Study 1: 110 pairs  |  8 workers
#   P=500 nm  |  Air 500nm  |  SiO2 50nm (hole ff=0.3)  |  CrSBr 30nm (hole ff=0.3)  |  SiO2 90nm  |  Si 100nm  |  Air 500nm
#   Study 1 [64/110  58%]  1.9 min elapsed,  ETC: 1.4 min  (1.8 s/task)
#   Study 1 [110/110  100%]  3.7 min elapsed,  ETC: 0.0 min  (2.0 s/task)
# Study 1 done in 3.7 min
# %--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--
# /Users/ezra/Desktop/LaNMP/python_scripts/RCWA/globalVersion/rcwa_output/CrSBrexample
# |
# |
# V
# Config saved as study1_A500nm_SiO2-50nm-hole-ff0.3nm_CrSBr-30nm-hole-ff0.3nm_SiO2-90nm_Si-100nm_rot45_nb25.json
# Data saved as study1_A500nm_SiO2-50nm-hole-ff0.3nm_CrSBr-30nm-hole-ff0.3nm_SiO2-90nm_Si-100nm_rot45_nb25.csv (16060 rows)
# Saved /Users/ezra/Desktop/LaNMP/python_scripts/RCWA/globalVersion/rcwa_output/CrSBrexample/study1_A500nm_SiO2-50nm-hole-ff0.3nm_CrSBr-30nm-hole-ff0.3nm_SiO2-90nm_Si-100nm_rot45.pdf
# %--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--
# Study 1: 110 pairs  |  8 workers
#   P=500 nm  |  Air 500nm  |  SiO2 50nm (hole ff=0.3)  |  CrSBr 50nm (hole ff=0.3)  |  SiO2 90nm  |  Si 100nm  |  Air 500nm
#   Study 1 [64/110  58%]  2.2 min elapsed,  ETC: 1.6 min  (2.0 s/task)
#   Study 1 [110/110  100%]  3.7 min elapsed,  ETC: 0.0 min  (2.0 s/task)
# Study 1 done in 3.7 min
# %--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--
# /Users/ezra/Desktop/LaNMP/python_scripts/RCWA/globalVersion/rcwa_output/CrSBrexample
# |
# |
# V
# Config saved as study1_A500nm_SiO2-50nm-hole-ff0.3nm_CrSBr-50nm-hole-ff0.3nm_SiO2-90nm_Si-100nm_rot45_nb25.json
# Data saved as study1_A500nm_SiO2-50nm-hole-ff0.3nm_CrSBr-50nm-hole-ff0.3nm_SiO2-90nm_Si-100nm_rot45_nb25.csv (16060 rows)
# Saved /Users/ezra/Desktop/LaNMP/python_scripts/RCWA/globalVersion/rcwa_output/CrSBrexample/study1_A500nm_SiO2-50nm-hole-ff0.3nm_CrSBr-50nm-hole-ff0.3nm_SiO2-90nm_Si-100nm_rot45.pdf
# %--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--
# Study 1: 110 pairs  |  8 workers
#   P=500 nm  |  Air 500nm  |  SiO2 50nm (hole ff=0.3)  |  CrSBr 80nm (hole ff=0.3)  |  SiO2 90nm  |  Si 100nm  |  Air 500nm
#   Study 1 [64/110  58%]  2.1 min elapsed,  ETC: 1.5 min  (2.0 s/task)
#   Study 1 [110/110  100%]  3.5 min elapsed,  ETC: 0.0 min  (1.9 s/task)
# Study 1 done in 3.5 min
# %--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--
# /Users/ezra/Desktop/LaNMP/python_scripts/RCWA/globalVersion/rcwa_output/CrSBrexample
# |
# |
# V
# Config saved as study1_A500nm_SiO2-50nm-hole-ff0.3nm_CrSBr-80nm-hole-ff0.3nm_SiO2-90nm_Si-100nm_rot45_nb25.json
# Data saved as study1_A500nm_SiO2-50nm-hole-ff0.3nm_CrSBr-80nm-hole-ff0.3nm_SiO2-90nm_Si-100nm_rot45_nb25.csv (16060 rows)
# Saved /Users/ezra/Desktop/LaNMP/python_scripts/RCWA/globalVersion/rcwa_output/CrSBrexample/study1_A500nm_SiO2-50nm-hole-ff0.3nm_CrSBr-80nm-hole-ff0.3nm_SiO2-90nm_Si-100nm_rot45.pdf
# %--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--
# Study 1: 110 pairs  |  8 workers
#   P=500 nm  |  Air 500nm  |  SiO2 50nm (hole ff=0.5)  |  CrSBr 30nm (hole ff=0.5)  |  SiO2 90nm  |  Si 100nm  |  Air 500nm
#   Study 1 [64/110  58%]  1.9 min elapsed,  ETC: 1.4 min  (1.8 s/task)
#   Study 1 [110/110  100%]  3.3 min elapsed,  ETC: 0.0 min  (1.8 s/task)
# Study 1 done in 3.3 min
# %--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--
# /Users/ezra/Desktop/LaNMP/python_scripts/RCWA/globalVersion/rcwa_output/CrSBrexample
# |
# |
# V
# Config saved as study1_A500nm_SiO2-50nm-hole-ff0.5nm_CrSBr-30nm-hole-ff0.5nm_SiO2-90nm_Si-100nm_rot00_nb25.json
# Data saved as study1_A500nm_SiO2-50nm-hole-ff0.5nm_CrSBr-30nm-hole-ff0.5nm_SiO2-90nm_Si-100nm_rot00_nb25.csv (16060 rows)
# Saved /Users/ezra/Desktop/LaNMP/python_scripts/RCWA/globalVersion/rcwa_output/CrSBrexample/study1_A500nm_SiO2-50nm-hole-ff0.5nm_CrSBr-30nm-hole-ff0.5nm_SiO2-90nm_Si-100nm_rot00.pdf
# %--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--
# Study 1: 110 pairs  |  8 workers
#   P=500 nm  |  Air 500nm  |  SiO2 50nm (hole ff=0.5)  |  CrSBr 50nm (hole ff=0.5)  |  SiO2 90nm  |  Si 100nm  |  Air 500nm
#   Study 1 [64/110  58%]  1.9 min elapsed,  ETC: 1.4 min  (1.8 s/task)
#   Study 1 [110/110  100%]  3.3 min elapsed,  ETC: 0.0 min  (1.8 s/task)
# Study 1 done in 3.3 min
# %--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--
# /Users/ezra/Desktop/LaNMP/python_scripts/RCWA/globalVersion/rcwa_output/CrSBrexample
# |
# |
# V
# Config saved as study1_A500nm_SiO2-50nm-hole-ff0.5nm_CrSBr-50nm-hole-ff0.5nm_SiO2-90nm_Si-100nm_rot00_nb25.json
# Data saved as study1_A500nm_SiO2-50nm-hole-ff0.5nm_CrSBr-50nm-hole-ff0.5nm_SiO2-90nm_Si-100nm_rot00_nb25.csv (16060 rows)
# Saved /Users/ezra/Desktop/LaNMP/python_scripts/RCWA/globalVersion/rcwa_output/CrSBrexample/study1_A500nm_SiO2-50nm-hole-ff0.5nm_CrSBr-50nm-hole-ff0.5nm_SiO2-90nm_Si-100nm_rot00.pdf
# %--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--
# Study 1: 110 pairs  |  8 workers
#   P=500 nm  |  Air 500nm  |  SiO2 50nm (hole ff=0.5)  |  CrSBr 80nm (hole ff=0.5)  |  SiO2 90nm  |  Si 100nm  |  Air 500nm
#   Study 1 [64/110  58%]  1.9 min elapsed,  ETC: 1.4 min  (1.8 s/task)
#   Study 1 [110/110  100%]  3.3 min elapsed,  ETC: 0.0 min  (1.8 s/task)
# Study 1 done in 3.3 min
# %--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--
# /Users/ezra/Desktop/LaNMP/python_scripts/RCWA/globalVersion/rcwa_output/CrSBrexample
# |
# |
# V
# Config saved as study1_A500nm_SiO2-50nm-hole-ff0.5nm_CrSBr-80nm-hole-ff0.5nm_SiO2-90nm_Si-100nm_rot00_nb25.json
# Data saved as study1_A500nm_SiO2-50nm-hole-ff0.5nm_CrSBr-80nm-hole-ff0.5nm_SiO2-90nm_Si-100nm_rot00_nb25.csv (16060 rows)
# Saved /Users/ezra/Desktop/LaNMP/python_scripts/RCWA/globalVersion/rcwa_output/CrSBrexample/study1_A500nm_SiO2-50nm-hole-ff0.5nm_CrSBr-80nm-hole-ff0.5nm_SiO2-90nm_Si-100nm_rot00.pdf
# %--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--
# Study 1: 110 pairs  |  8 workers
#   P=500 nm  |  Air 500nm  |  SiO2 50nm (hole ff=0.5)  |  CrSBr 30nm (hole ff=0.5)  |  SiO2 90nm  |  Si 100nm  |  Air 500nm
#   Study 1 [64/110  58%]  1.9 min elapsed,  ETC: 1.4 min  (1.8 s/task)
#   Study 1 [110/110  100%]  3.3 min elapsed,  ETC: 0.0 min  (1.8 s/task)
# Study 1 done in 3.3 min
# %--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--
# /Users/ezra/Desktop/LaNMP/python_scripts/RCWA/globalVersion/rcwa_output/CrSBrexample
# |
# |
# V
# Config saved as study1_A500nm_SiO2-50nm-hole-ff0.5nm_CrSBr-30nm-hole-ff0.5nm_SiO2-90nm_Si-100nm_rot45_nb25.json
# Data saved as study1_A500nm_SiO2-50nm-hole-ff0.5nm_CrSBr-30nm-hole-ff0.5nm_SiO2-90nm_Si-100nm_rot45_nb25.csv (16060 rows)
# Saved /Users/ezra/Desktop/LaNMP/python_scripts/RCWA/globalVersion/rcwa_output/CrSBrexample/study1_A500nm_SiO2-50nm-hole-ff0.5nm_CrSBr-30nm-hole-ff0.5nm_SiO2-90nm_Si-100nm_rot45.pdf
# %--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--
# Study 1: 110 pairs  |  8 workers
#   P=500 nm  |  Air 500nm  |  SiO2 50nm (hole ff=0.5)  |  CrSBr 50nm (hole ff=0.5)  |  SiO2 90nm  |  Si 100nm  |  Air 500nm
#   Study 1 [64/110  58%]  1.9 min elapsed,  ETC: 1.4 min  (1.8 s/task)
#   Study 1 [110/110  100%]  3.3 min elapsed,  ETC: 0.0 min  (1.8 s/task)
# Study 1 done in 3.3 min
# %--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--
# /Users/ezra/Desktop/LaNMP/python_scripts/RCWA/globalVersion/rcwa_output/CrSBrexample
# |
# |
# V
# Config saved as study1_A500nm_SiO2-50nm-hole-ff0.5nm_CrSBr-50nm-hole-ff0.5nm_SiO2-90nm_Si-100nm_rot45_nb25.json
# Data saved as study1_A500nm_SiO2-50nm-hole-ff0.5nm_CrSBr-50nm-hole-ff0.5nm_SiO2-90nm_Si-100nm_rot45_nb25.csv (16060 rows)
# Saved /Users/ezra/Desktop/LaNMP/python_scripts/RCWA/globalVersion/rcwa_output/CrSBrexample/study1_A500nm_SiO2-50nm-hole-ff0.5nm_CrSBr-50nm-hole-ff0.5nm_SiO2-90nm_Si-100nm_rot45.pdf
# %--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--
# Study 1: 110 pairs  |  8 workers
#   P=500 nm  |  Air 500nm  |  SiO2 50nm (hole ff=0.5)  |  CrSBr 80nm (hole ff=0.5)  |  SiO2 90nm  |  Si 100nm  |  Air 500nm
#   Study 1 [64/110  58%]  1.9 min elapsed,  ETC: 1.3 min  (1.7 s/task)
#   Study 1 [110/110  100%]  3.3 min elapsed,  ETC: 0.0 min  (1.8 s/task)
# Study 1 done in 3.3 min
# %--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--
# /Users/ezra/Desktop/LaNMP/python_scripts/RCWA/globalVersion/rcwa_output/CrSBrexample
# |
# |
# V
# Config saved as study1_A500nm_SiO2-50nm-hole-ff0.5nm_CrSBr-80nm-hole-ff0.5nm_SiO2-90nm_Si-100nm_rot45_nb25.json
# Data saved as study1_A500nm_SiO2-50nm-hole-ff0.5nm_CrSBr-80nm-hole-ff0.5nm_SiO2-90nm_Si-100nm_rot45_nb25.csv (16060 rows)
# Saved /Users/ezra/Desktop/LaNMP/python_scripts/RCWA/globalVersion/rcwa_output/CrSBrexample/study1_A500nm_SiO2-50nm-hole-ff0.5nm_CrSBr-80nm-hole-ff0.5nm_SiO2-90nm_Si-100nm_rot45.pdf
# %--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--
# Study 1: 110 pairs  |  8 workers
#   P=500 nm  |  Air 500nm  |  SiO2 50nm (hole ff=0.7)  |  CrSBr 30nm (hole ff=0.7)  |  SiO2 90nm  |  Si 100nm  |  Air 500nm
#   Study 1 [64/110  58%]  1.9 min elapsed,  ETC: 1.4 min  (1.8 s/task)
#   Study 1 [110/110  100%]  3.2 min elapsed,  ETC: 0.0 min  (1.8 s/task)
# Study 1 done in 3.2 min
# %--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--
# /Users/ezra/Desktop/LaNMP/python_scripts/RCWA/globalVersion/rcwa_output/CrSBrexample
# |
# |
# V
# Config saved as study1_A500nm_SiO2-50nm-hole-ff0.7nm_CrSBr-30nm-hole-ff0.7nm_SiO2-90nm_Si-100nm_rot00_nb25.json
# Data saved as study1_A500nm_SiO2-50nm-hole-ff0.7nm_CrSBr-30nm-hole-ff0.7nm_SiO2-90nm_Si-100nm_rot00_nb25.csv (16060 rows)
# Saved /Users/ezra/Desktop/LaNMP/python_scripts/RCWA/globalVersion/rcwa_output/CrSBrexample/study1_A500nm_SiO2-50nm-hole-ff0.7nm_CrSBr-30nm-hole-ff0.7nm_SiO2-90nm_Si-100nm_rot00.pdf
# %--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--
# Study 1: 110 pairs  |  8 workers
#   P=500 nm  |  Air 500nm  |  SiO2 50nm (hole ff=0.7)  |  CrSBr 50nm (hole ff=0.7)  |  SiO2 90nm  |  Si 100nm  |  Air 500nm
#   Study 1 [64/110  58%]  2.0 min elapsed,  ETC: 1.4 min  (1.8 s/task)
#   Study 1 [110/110  100%]  3.4 min elapsed,  ETC: 0.0 min  (1.8 s/task)
# Study 1 done in 3.4 min
# %--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--
# /Users/ezra/Desktop/LaNMP/python_scripts/RCWA/globalVersion/rcwa_output/CrSBrexample
# |
# |
# V
# Config saved as study1_A500nm_SiO2-50nm-hole-ff0.7nm_CrSBr-50nm-hole-ff0.7nm_SiO2-90nm_Si-100nm_rot00_nb25.json
# Data saved as study1_A500nm_SiO2-50nm-hole-ff0.7nm_CrSBr-50nm-hole-ff0.7nm_SiO2-90nm_Si-100nm_rot00_nb25.csv (16060 rows)
# Saved /Users/ezra/Desktop/LaNMP/python_scripts/RCWA/globalVersion/rcwa_output/CrSBrexample/study1_A500nm_SiO2-50nm-hole-ff0.7nm_CrSBr-50nm-hole-ff0.7nm_SiO2-90nm_Si-100nm_rot00.pdf
# %--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--
# Study 1: 110 pairs  |  8 workers
#   P=500 nm  |  Air 500nm  |  SiO2 50nm (hole ff=0.7)  |  CrSBr 80nm (hole ff=0.7)  |  SiO2 90nm  |  Si 100nm  |  Air 500nm
#   Study 1 [64/110  58%]  2.0 min elapsed,  ETC: 1.4 min  (1.8 s/task)
#   Study 1 [110/110  100%]  3.6 min elapsed,  ETC: 0.0 min  (2.0 s/task)
# Study 1 done in 3.6 min
# %--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--
# /Users/ezra/Desktop/LaNMP/python_scripts/RCWA/globalVersion/rcwa_output/CrSBrexample
# |
# |
# V
# Config saved as study1_A500nm_SiO2-50nm-hole-ff0.7nm_CrSBr-80nm-hole-ff0.7nm_SiO2-90nm_Si-100nm_rot00_nb25.json
# Data saved as study1_A500nm_SiO2-50nm-hole-ff0.7nm_CrSBr-80nm-hole-ff0.7nm_SiO2-90nm_Si-100nm_rot00_nb25.csv (16060 rows)
# Saved /Users/ezra/Desktop/LaNMP/python_scripts/RCWA/globalVersion/rcwa_output/CrSBrexample/study1_A500nm_SiO2-50nm-hole-ff0.7nm_CrSBr-80nm-hole-ff0.7nm_SiO2-90nm_Si-100nm_rot00.pdf
# %--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--
# Study 1: 110 pairs  |  8 workers
#   P=500 nm  |  Air 500nm  |  SiO2 50nm (hole ff=0.7)  |  CrSBr 30nm (hole ff=0.7)  |  SiO2 90nm  |  Si 100nm  |  Air 500nm
#   Study 1 [64/110  58%]  2.1 min elapsed,  ETC: 1.5 min  (2.0 s/task)
#   Study 1 [110/110  100%]  3.6 min elapsed,  ETC: 0.0 min  (2.0 s/task)
# Study 1 done in 3.6 min
# %--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--
# /Users/ezra/Desktop/LaNMP/python_scripts/RCWA/globalVersion/rcwa_output/CrSBrexample
# |
# |
# V
# Config saved as study1_A500nm_SiO2-50nm-hole-ff0.7nm_CrSBr-30nm-hole-ff0.7nm_SiO2-90nm_Si-100nm_rot45_nb25.json
# Data saved as study1_A500nm_SiO2-50nm-hole-ff0.7nm_CrSBr-30nm-hole-ff0.7nm_SiO2-90nm_Si-100nm_rot45_nb25.csv (16060 rows)
# Saved /Users/ezra/Desktop/LaNMP/python_scripts/RCWA/globalVersion/rcwa_output/CrSBrexample/study1_A500nm_SiO2-50nm-hole-ff0.7nm_CrSBr-30nm-hole-ff0.7nm_SiO2-90nm_Si-100nm_rot45.pdf
# %--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--
# Study 1: 110 pairs  |  8 workers
#   P=500 nm  |  Air 500nm  |  SiO2 50nm (hole ff=0.7)  |  CrSBr 50nm (hole ff=0.7)  |  SiO2 90nm  |  Si 100nm  |  Air 500nm
#   Study 1 [64/110  58%]  2.0 min elapsed,  ETC: 1.4 min  (1.9 s/task)
#   Study 1 [110/110  100%]  3.5 min elapsed,  ETC: 0.0 min  (1.9 s/task)
# Study 1 done in 3.5 min
# %--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--
# /Users/ezra/Desktop/LaNMP/python_scripts/RCWA/globalVersion/rcwa_output/CrSBrexample
# |
# |
# V
# Config saved as study1_A500nm_SiO2-50nm-hole-ff0.7nm_CrSBr-50nm-hole-ff0.7nm_SiO2-90nm_Si-100nm_rot45_nb25.json
# Data saved as study1_A500nm_SiO2-50nm-hole-ff0.7nm_CrSBr-50nm-hole-ff0.7nm_SiO2-90nm_Si-100nm_rot45_nb25.csv (16060 rows)
# Saved /Users/ezra/Desktop/LaNMP/python_scripts/RCWA/globalVersion/rcwa_output/CrSBrexample/study1_A500nm_SiO2-50nm-hole-ff0.7nm_CrSBr-50nm-hole-ff0.7nm_SiO2-90nm_Si-100nm_rot45.pdf
# %--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--
# Study 1: 110 pairs  |  8 workers
#   P=500 nm  |  Air 500nm  |  SiO2 50nm (hole ff=0.7)  |  CrSBr 80nm (hole ff=0.7)  |  SiO2 90nm  |  Si 100nm  |  Air 500nm
#   Study 1 [64/110  58%]  2.1 min elapsed,  ETC: 1.5 min  (2.0 s/task)
#   Study 1 [110/110  100%]  3.7 min elapsed,  ETC: 0.0 min  (2.0 s/task)
# Study 1 done in 3.7 min
# %--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--
# /Users/ezra/Desktop/LaNMP/python_scripts/RCWA/globalVersion/rcwa_output/CrSBrexample
# |
# |
# V
# Config saved as study1_A500nm_SiO2-50nm-hole-ff0.7nm_CrSBr-80nm-hole-ff0.7nm_SiO2-90nm_Si-100nm_rot45_nb25.json
# Data saved as study1_A500nm_SiO2-50nm-hole-ff0.7nm_CrSBr-80nm-hole-ff0.7nm_SiO2-90nm_Si-100nm_rot45_nb25.csv (16060 rows)
# Saved /Users/ezra/Desktop/LaNMP/python_scripts/RCWA/globalVersion/rcwa_output/CrSBrexample/study1_A500nm_SiO2-50nm-hole-ff0.7nm_CrSBr-80nm-hole-ff0.7nm_SiO2-90nm_Si-100nm_rot45.pdf
# %--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--%--

# %%
importlib.reload(ru)
# Out:
# <module 'rcwa_utils' from '/Users/ezra/gitprojects/rcwa-phc/rcwa_utils.py'>

# %% [markdown]
# ### **6.2.1 Study 2 (kx vs. ky)**

# %%
df_study2 = run_study2(conf, print_every=128)
# Out:
# Study 2: rot=0  |  7700 pairs  |  8 workers
#   P=535 nm  |  Air 500nm  |  ReS2 70nm (cuboids w0=250 a=0.6)  |  Air 500nm
#   Study 2 [128/7700  2%]  0.8 min elapsed,  ETC: 47.3 min  (0.4 s/task)
#   Study 2 [256/7700  3%]  1.6 min elapsed,  ETC: 45.9 min  (0.4 s/task)
#   Study 2 [384/7700  5%]  2.4 min elapsed,  ETC: 44.8 min  (0.4 s/task)
#   Study 2 [512/7700  7%]  3.1 min elapsed,  ETC: 43.9 min  (0.4 s/task)
#   Study 2 [640/7700  8%]  3.9 min elapsed,  ETC: 43.1 min  (0.4 s/task)
#   Study 2 [768/7700  10%]  4.7 min elapsed,  ETC: 42.4 min  (0.4 s/task)
#   Study 2 [896/7700  12%]  5.5 min elapsed,  ETC: 41.6 min  (0.4 s/task)
#   Study 2 [1024/7700  13%]  6.3 min elapsed,  ETC: 41.0 min  (0.4 s/task)
#   Study 2 [1152/7700  15%]  7.1 min elapsed,  ETC: 40.3 min  (0.4 s/task)
#   Study 2 [1280/7700  17%]  7.9 min elapsed,  ETC: 39.5 min  (0.4 s/task)
#   Study 2 [1408/7700  18%]  8.7 min elapsed,  ETC: 38.8 min  (0.4 s/task)
#   Study 2 [1536/7700  20%]  9.5 min elapsed,  ETC: 38.1 min  (0.4 s/task)
#   Study 2 [1664/7700  22%]  10.3 min elapsed,  ETC: 37.3 min  (0.4 s/task)
#   Study 2 [1792/7700  23%]  11.1 min elapsed,  ETC: 36.5 min  (0.4 s/task)
#   Study 2 [1920/7700  25%]  11.8 min elapsed,  ETC: 35.7 min  (0.4 s/task)
#   Study 2 [2048/7700  27%]  12.6 min elapsed,  ETC: 34.9 min  (0.4 s/task)
#   Study 2 [2176/7700  28%]  13.4 min elapsed,  ETC: 34.1 min  (0.4 s/task)
#   Study 2 [2304/7700  30%]  14.2 min elapsed,  ETC: 33.3 min  (0.4 s/task)
#   Study 2 [2432/7700  32%]  15.0 min elapsed,  ETC: 32.5 min  (0.4 s/task)
#   Study 2 [2560/7700  33%]  15.8 min elapsed,  ETC: 31.7 min  (0.4 s/task)
#   Study 2 [2688/7700  35%]  16.6 min elapsed,  ETC: 30.9 min  (0.4 s/task)
#   Study 2 [2816/7700  37%]  17.3 min elapsed,  ETC: 30.1 min  (0.4 s/task)
#   Study 2 [2944/7700  38%]  18.2 min elapsed,  ETC: 29.3 min  (0.4 s/task)
#   Study 2 [3072/7700  40%]  18.9 min elapsed,  ETC: 28.5 min  (0.4 s/task)
#   Study 2 [3200/7700  42%]  19.7 min elapsed,  ETC: 27.7 min  (0.4 s/task)
#   Study 2 [3328/7700  43%]  20.5 min elapsed,  ETC: 26.9 min  (0.4 s/task)
#   Study 2 [3456/7700  45%]  21.2 min elapsed,  ETC: 26.1 min  (0.4 s/task)
#   Study 2 [3584/7700  47%]  22.0 min elapsed,  ETC: 25.3 min  (0.4 s/task)
#   Study 2 [3712/7700  48%]  22.8 min elapsed,  ETC: 24.5 min  (0.4 s/task)
#   Study 2 [3840/7700  50%]  23.6 min elapsed,  ETC: 23.7 min  (0.4 s/task)
#   Study 2 [3968/7700  52%]  24.3 min elapsed,  ETC: 22.9 min  (0.4 s/task)
#   Study 2 [4096/7700  53%]  25.1 min elapsed,  ETC: 22.1 min  (0.4 s/task)
#   Study 2 [4224/7700  55%]  25.9 min elapsed,  ETC: 21.3 min  (0.4 s/task)
#   Study 2 [4352/7700  57%]  26.6 min elapsed,  ETC: 20.5 min  (0.4 s/task)
#   Study 2 [4480/7700  58%]  27.4 min elapsed,  ETC: 19.7 min  (0.4 s/task)
#   Study 2 [4608/7700  60%]  28.2 min elapsed,  ETC: 18.9 min  (0.4 s/task)
#   Study 2 [4736/7700  62%]  29.0 min elapsed,  ETC: 18.1 min  (0.4 s/task)
#   Study 2 [4864/7700  63%]  29.7 min elapsed,  ETC: 17.3 min  (0.4 s/task)
#   Study 2 [4992/7700  65%]  30.5 min elapsed,  ETC: 16.5 min  (0.4 s/task)
#   Study 2 [5120/7700  66%]  31.2 min elapsed,  ETC: 15.7 min  (0.4 s/task)
#   Study 2 [5248/7700  68%]  32.0 min elapsed,  ETC: 15.0 min  (0.4 s/task)
#   Study 2 [5376/7700  70%]  32.8 min elapsed,  ETC: 14.2 min  (0.4 s/task)
#   Study 2 [5504/7700  71%]  33.6 min elapsed,  ETC: 13.4 min  (0.4 s/task)
#   Study 2 [5632/7700  73%]  34.3 min elapsed,  ETC: 12.6 min  (0.4 s/task)
#   Study 2 [5760/7700  75%]  35.1 min elapsed,  ETC: 11.8 min  (0.4 s/task)
#   Study 2 [5888/7700  76%]  35.9 min elapsed,  ETC: 11.0 min  (0.4 s/task)
#   Study 2 [6016/7700  78%]  36.6 min elapsed,  ETC: 10.2 min  (0.4 s/task)
#   Study 2 [6144/7700  80%]  37.4 min elapsed,  ETC: 9.5 min  (0.4 s/task)
#   Study 2 [6272/7700  81%]  38.1 min elapsed,  ETC: 8.7 min  (0.4 s/task)
#   Study 2 [6400/7700  83%]  38.9 min elapsed,  ETC: 7.9 min  (0.4 s/task)
#   Study 2 [6528/7700  85%]  39.7 min elapsed,  ETC: 7.1 min  (0.4 s/task)
#   Study 2 [6656/7700  86%]  40.4 min elapsed,  ETC: 6.3 min  (0.4 s/task)
#   Study 2 [6784/7700  88%]  41.2 min elapsed,  ETC: 5.6 min  (0.4 s/task)
#   Study 2 [6912/7700  90%]  42.0 min elapsed,  ETC: 4.8 min  (0.4 s/task)
#   Study 2 [7040/7700  91%]  42.7 min elapsed,  ETC: 4.0 min  (0.4 s/task)
#   Study 2 [7168/7700  93%]  43.5 min elapsed,  ETC: 3.2 min  (0.4 s/task)
#   Study 2 [7296/7700  95%]  44.3 min elapsed,  ETC: 2.5 min  (0.4 s/task)
#   Study 2 [7424/7700  96%]  45.0 min elapsed,  ETC: 1.7 min  (0.4 s/task)
#   Study 2 [7552/7700  98%]  45.8 min elapsed,  ETC: 0.9 min  (0.4 s/task)
#   Study 2 [7680/7700  100%]  46.6 min elapsed,  ETC: 0.1 min  (0.4 s/task)
#   Study 2 [7700/7700  100%]  46.7 min elapsed,  ETC: 0.0 min  (0.4 s/task)
# /Users/ezra/Desktop/LaNMP/python_scripts/RCWA/globalVersion/rcwa_output/ReS2Example
# |
# |
# V
# Config saved as study2_A535nm_ReS2-70nm-cub-w0250nm-a0.6_rot00_nb25.json
# Study 2 done in 47.0 min  ->  study2_A535nm_ReS2-70nm-cub-w0250nm-a0.6_rot00_nb25.csv  (523600 rows)

# %%
kxkyvid = animate_kxky(df_study2, conf, preset = 'res2')
# Out:
# Pre-computing 68 frames... done.
# Saved 68 frames -> study2_A535nm_ReS2-70nm-cub-w0250nm-a0.6_rot00_nb25_kxky.mp4

# %%
importlib.reload(ru)
# Out:
# <module 'rcwa_utils' from '/Users/ezra/gitprojects/rcwa-phc/rcwa_utils.py'>

# %%
polvid = ru.animate_polarization(df_study2, conf)
# Out:
# Pre-computing 68 frames... done.
# Saved 68 frames -> study2_A535nm_ReS2-70nm-cub-w0250nm-a0.6_rot00_nb25_polmap_sin.mp4

# %% [markdown]
# ### **6.3.1 Study 3 (Modes)**

# %%
df_study3 = ru.run_study3(conf, lam_center_nm=840, lam_range_nm=30)
# importlib.reload(ru)

# %% [markdown]
# ### **6.4 Load Saved Data**

# %% [markdown]
# ```python
# ex_conf_loaded = ru.RCWAConfig.load('/Your_path_here.json')
# ```

# %%
# ── Load saved data with config ────────────────────────────────────────────────────────────
# NOTE: As of 2026 May 12, every study that gets run will automatically save with
# a config file of the same filename and extension .json. This config file
# contains all study parameters and must be recalled to plot the data.

df_load, conf_load = ru.load_study('/Users/ezra/Desktop/LaNMP/python_scripts/RCWA/globalVersion/rcwa_output/study1_A500nm_SiO2-50nm-hole-ff0.5_CrSBr-70nm-hole-ff0.5_SiO2-100nm_rot00_nb25.json')
conf_load.verify_config()

# %% [markdown]
# # **7. Plotting**

# %% [markdown]
# ## Appendix
#
# ### Geometry options
#
# | GEOMETRY | Description |
# |---|---|
# | `'pillar'` | Single square pillar in air background |
# | `'hole'` | Single square air hole in slab |
# | `'cuboids'` | Two asymmetric square pillars (diagonal arrangement) |
#
# ### Material notes
# - **CrSBr**: dispersive anisotropic tensor from interpolated n,k data. `PHIZ_VALS` sweeps the b-axis rotation angle.
# - **ReS2**: non-dispersive birefringent dielectric. `EPS0` and `DELTA_EPS` set the permittivities directly.
#
# ### Key conventions
# - s-polarisation = ⊥ plane of incidence (TE in COMSOL, = ŷ at azim=0°, normal incidence)
# - p-polarisation = ∥ plane of incidence (TM in COMSOL)
# - Circular: R = (s+ip)/√2, L = (s−ip)/√2
# - CD = T_RR − T_LL (positive = more right-circular transmitted)
# - S3 > 0: right-elliptical output for s-pol input
#
# ### S4 API reference
# | Call | Purpose |
# |---|---|
# | `S.SetFrequency(1/lam)` | Set wavelength (lam in same units as lattice) |
# | `S.SetMaterial(Name, Epsilon)` | Update material (cheap, reuses geometry) |
# | `S.SetExcitationPlanewave(...)` | Set incident field |
# | `S.GetFieldsOnGridNumpy(z, (N,N))` | Fast field grid → shape (N,N,3) |
# | `S.GetPowerFlux(Layer, zOffset)` | T/R power flux |
# | `S.GetBasisSet()` | List of (i,j) G-vectors |
